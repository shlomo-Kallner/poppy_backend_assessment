# %%
from requests import Session

url = 'https://clinicaltables.nlm.nih.gov/api/rxterms/v3/search'

baseParams = {
    # "df": "DISPLAY_NAME,DISPLAY_NAME_SYNONYM",
    "df": "DISPLAY_NAME_SYNONYM",
    # "ef": "STRENGTHS_AND_FORMS,RXCUIS,SXDG_RXCUI"
    "ef": "STRENGTHS_AND_FORMS,RXCUIS"
}

def fetch_data(name: str) -> list:
    with Session() as s:
        resp = s.get(url, params={"terms": name, **baseParams})
        resp.raise_for_status()
        return resp.json()

def transform_list(
    names: list[str], 
    # displays: list, 
    extra_data: dict
) -> list[dict]:

    results = []

    # transform the extra_data
    tmp_extras = { k: [(k, v1) for v1 in v] for k, v in extra_data.items() }

    tmp_ex_zipped = tuple(zip(*tmp_extras.values()))

    
    # for name, display, extra in zip(names, displays, tmp_ex_zipped):

    #     print(f"{name=}\n{display=}\n{extra=}\n\n")
    
    for name, extra in zip(names, tmp_ex_zipped):

        print(f"{name=}\n{extra=}\n\n")

        nx_extra = { t[0]: [ (t[0], n) for n in t[1] ] for t in extra }

        print(f"{nx_extra=}\n\n")

        nz_extras = [ dict(t) for t in zip(*nx_extra.values()) ]

        print(f"{nz_extras=}\n\n")

        tmp = [
            {
                "name": name,
                **extra_data
            } for extra_data in nz_extras
        ]

        for item in tmp:
            print(f"{item=}\n\n\n\n")

        results.extend(tmp)

    return results


dl1 = fetch_data("tyl")

print(f"[{len(dl1)}]@[{type(dl1)}] {dl1=}")

transformed_List = transform_list(
    dl1[1], 
    # dl1[3], 
    dl1[2]
)
# Out:
# [4]@[<class 'list'>] dl1=[9, ['TYLENOL WITH CODEINE (Oral Pill)', 'TYLENOL (Oral Pill)', 'TYLENOL (Oral Liquid)', 'TYLENOL PM (Oral Liquid)', 'TYLENOL PM (Oral Pill)', 'TYLENOL XR (Oral Pill)', 'Tyloxapol (Ophthalmic)'], {'STRENGTHS_AND_FORMS': [['300-30 mg Tab', '300-60 mg Tab'], ['325 mg Cap', '325 mg Tab', '500 mg Tab'], ['160 mg/5ml Susp'], ['500-25 mg/15ml Sol'], ['500-25 mg Tab'], ['650 mg 8 HR XR Tab'], ['0.25% Sol']], 'RXCUIS': [['993837', '993892'], ['1738139', '209387', '209459'], ['828555'], ['1092375'], ['1092378'], ['1243440'], ['204644']]}, [[''], [''], [''], [''], [''], [''], ['']]]
# name='TYLENOL WITH CODEINE (Oral Pill)'
# extra=(('STRENGTHS_AND_FORMS', ['300-30 mg Tab', '300-60 mg Tab']), ('RXCUIS', ['993837', '993892']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '300-30 mg Tab'), ('STRENGTHS_AND_FORMS', '300-60 mg Tab')], 'RXCUIS': [('RXCUIS', '993837'), ('RXCUIS', '993892')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '300-30 mg Tab', 'RXCUIS': '993837'}, {'STRENGTHS_AND_FORMS': '300-60 mg Tab', 'RXCUIS': '993892'}]
#
#
# item={'name': 'TYLENOL WITH CODEINE (Oral Pill)', 'STRENGTHS_AND_FORMS': '300-30 mg Tab', 'RXCUIS': '993837'}
#
#
#
#
# item={'name': 'TYLENOL WITH CODEINE (Oral Pill)', 'STRENGTHS_AND_FORMS': '300-60 mg Tab', 'RXCUIS': '993892'}
#
#
#
#
# name='TYLENOL (Oral Pill)'
# extra=(('STRENGTHS_AND_FORMS', ['325 mg Cap', '325 mg Tab', '500 mg Tab']), ('RXCUIS', ['1738139', '209387', '209459']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '325 mg Cap'), ('STRENGTHS_AND_FORMS', '325 mg Tab'), ('STRENGTHS_AND_FORMS', '500 mg Tab')], 'RXCUIS': [('RXCUIS', '1738139'), ('RXCUIS', '209387'), ('RXCUIS', '209459')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '325 mg Cap', 'RXCUIS': '1738139'}, {'STRENGTHS_AND_FORMS': '325 mg Tab', 'RXCUIS': '209387'}, {'STRENGTHS_AND_FORMS': '500 mg Tab', 'RXCUIS': '209459'}]
#
#
# item={'name': 'TYLENOL (Oral Pill)', 'STRENGTHS_AND_FORMS': '325 mg Cap', 'RXCUIS': '1738139'}
#
#
#
#
# item={'name': 'TYLENOL (Oral Pill)', 'STRENGTHS_AND_FORMS': '325 mg Tab', 'RXCUIS': '209387'}
#
#
#
#
# item={'name': 'TYLENOL (Oral Pill)', 'STRENGTHS_AND_FORMS': '500 mg Tab', 'RXCUIS': '209459'}
#
#
#
#
# name='TYLENOL (Oral Liquid)'
# extra=(('STRENGTHS_AND_FORMS', ['160 mg/5ml Susp']), ('RXCUIS', ['828555']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '160 mg/5ml Susp')], 'RXCUIS': [('RXCUIS', '828555')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '160 mg/5ml Susp', 'RXCUIS': '828555'}]
#
#
# item={'name': 'TYLENOL (Oral Liquid)', 'STRENGTHS_AND_FORMS': '160 mg/5ml Susp', 'RXCUIS': '828555'}
#
#
#
#
# name='TYLENOL PM (Oral Liquid)'
# extra=(('STRENGTHS_AND_FORMS', ['500-25 mg/15ml Sol']), ('RXCUIS', ['1092375']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '500-25 mg/15ml Sol')], 'RXCUIS': [('RXCUIS', '1092375')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '500-25 mg/15ml Sol', 'RXCUIS': '1092375'}]
#
#
# item={'name': 'TYLENOL PM (Oral Liquid)', 'STRENGTHS_AND_FORMS': '500-25 mg/15ml Sol', 'RXCUIS': '1092375'}
#
#
#
#
# name='TYLENOL PM (Oral Pill)'
# extra=(('STRENGTHS_AND_FORMS', ['500-25 mg Tab']), ('RXCUIS', ['1092378']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '500-25 mg Tab')], 'RXCUIS': [('RXCUIS', '1092378')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '500-25 mg Tab', 'RXCUIS': '1092378'}]
#
#
# item={'name': 'TYLENOL PM (Oral Pill)', 'STRENGTHS_AND_FORMS': '500-25 mg Tab', 'RXCUIS': '1092378'}
#
#
#
#
# name='TYLENOL XR (Oral Pill)'
# extra=(('STRENGTHS_AND_FORMS', ['650 mg 8 HR XR Tab']), ('RXCUIS', ['1243440']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '650 mg 8 HR XR Tab')], 'RXCUIS': [('RXCUIS', '1243440')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '650 mg 8 HR XR Tab', 'RXCUIS': '1243440'}]
#
#
# item={'name': 'TYLENOL XR (Oral Pill)', 'STRENGTHS_AND_FORMS': '650 mg 8 HR XR Tab', 'RXCUIS': '1243440'}
#
#
#
#
# name='Tyloxapol (Ophthalmic)'
# extra=(('STRENGTHS_AND_FORMS', ['0.25% Sol']), ('RXCUIS', ['204644']))
#
#
# nx_extra={'STRENGTHS_AND_FORMS': [('STRENGTHS_AND_FORMS', '0.25% Sol')], 'RXCUIS': [('RXCUIS', '204644')]}
#
#
# nz_extras=[{'STRENGTHS_AND_FORMS': '0.25% Sol', 'RXCUIS': '204644'}]
#
#
# item={'name': 'Tyloxapol (Ophthalmic)', 'STRENGTHS_AND_FORMS': '0.25% Sol', 'RXCUIS': '204644'}
